# %% [markdown]
# # Кластеризация (бонус)
#
# **Датасет:** Mall Customers

# %% [markdown]
# ## Цели
#
# - Изучить и применить на практике ключевые концепции темы
# - Провести полный цикл: загрузка данных → EDA → препроцессинг → модель → оценка
# - Сделать выводы и зафиксировать наблюдения

# %% [markdown]
# ## Содержание
#
# 1. EDA данных
# 2. K-Means: подбор k (метод локтя, silhouette)
# 3. DBSCAN
# 4. Иерархическая кластеризация
# 5. PCA для визуализации
# 6. Интерпретация кластеров
# 7. Выводы

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %matplotlib inline

# %%
df = pd.read_csv('../data/mall-customers/Mall_Customers.csv')
print(df.shape)
df.head()

# %% [markdown]
# ## EDA
#
# ---

# %%
# TODO

# %% [markdown]
# ## Препроцессинг
#
# ---

# %%
# TODO

# %% [markdown]
# ## Модель
#
# ---

# %%
# TODO

# %% [markdown]
# ## Оценка
#
# ---

# %%
# TODO

# %% [markdown]
# ## Выводы
#
# ---

# %%
# TODO

# %% [markdown]
# ## Итоги
#
# | Модель | Метрика | Значение |
# |-------|---------|----------|
# | ... | ... | ... |
#
# **Ключевые наблюдения:**
#
# -
# -
# -
