# %% [markdown]
# # Мультиклассовая классификация
#
# **Датасет:** Fashion-MNIST

# %% [markdown]
# ## Цели
#
# - Изучить и применить на практике ключевые концепции темы
# - Провести полный цикл: загрузка данных → EDA → препроцессинг → модель → оценка
# - Сделать выводы и зафиксировать наблюдения

# %% [markdown]
# ## Содержание
#
# 1. Загрузка Fashion-MNIST
# 2. EDA: примеры изображений
# 3. Softmax (LogisticRegression multinomial)
# 4. KNN
# 5. SVM
# 6. Сравнение метрик
# 7. Выводы

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
# Fashion-MNIST загружается автоматически
fashion = fetch_openml('Fashion-MNIST', version=1, as_frame=False, parser='auto')
X, y = fashion.data, fashion.target
print(X.shape, y.shape)

# %% [markdown]
# ## EDA
#
# ---

# %%
# TODO

# %% [markdown]
# ## Препроцессинг
#
# ---

# %%
# TODO

# %% [markdown]
# ## Модель
#
# ---

# %%
# TODO

# %% [markdown]
# ## Оценка
#
# ---

# %%
# TODO

# %% [markdown]
# ## Выводы
#
# ---

# %%
# TODO

# %% [markdown]
# ## Итоги
#
# | Модель | Метрика | Значение |
# |-------|---------|----------|
# | ... | ... | ... |
#
# **Ключевые наблюдения:**
#
# -
# -
# -
