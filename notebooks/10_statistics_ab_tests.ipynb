# %% [markdown]
# # Статистика и A/B тесты
#
# **Датасет:** Синтетические данные

# %% [markdown]
# ## Цели
#
# - Изучить и применить на практике ключевые концепции темы
# - Провести полный цикл: загрузка данных → EDA → препроцессинг → модель → оценка
# - Сделать выводы и зафиксировать наблюдения

# %% [markdown]
# ## Содержание
#
# 1. Доверительные интервалы
# 2. t-test (независимые выборки)
# 3. Критерий хи-квадрат
# 4. Bootstrap
# 5. Мощность теста и размер выборки
# 6. Множественные сравнения (поправка Бонферрони)
# 7. Выводы

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import ttest_ind, chi2_contingency

np.random.seed(42)
# %matplotlib inline

# %%
# Генерируем синтетические данные для A/B теста
np.random.seed(42)
n = 1000
control   = np.random.normal(loc=10.0, scale=2.0, size=n)
treatment = np.random.normal(loc=10.5, scale=2.0, size=n)
print(f'Control mean: {control.mean():.3f}, Treatment mean: {treatment.mean():.3f}')

# %% [markdown]
# ## EDA
#
# ---

# %%
# TODO

# %% [markdown]
# ## Препроцессинг
#
# ---

# %%
# TODO

# %% [markdown]
# ## Модель
#
# ---

# %%
# TODO

# %% [markdown]
# ## Оценка
#
# ---

# %%
# TODO

# %% [markdown]
# ## Выводы
#
# ---

# %%
# TODO

# %% [markdown]
# ## Итоги
#
# | Модель | Метрика | Значение |
# |-------|---------|----------|
# | ... | ... | ... |
#
# **Ключевые наблюдения:**
#
# -
# -
# -
