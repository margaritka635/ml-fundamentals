# %% [markdown]
# # SQL для аналитики
#
# **Датасет:** SQLite (любой датасет)

# %% [markdown]
# ## Цели
#
# - Изучить и применить на практике ключевые концепции темы
# - Провести полный цикл: загрузка данных → EDA → препроцессинг → модель → оценка
# - Сделать выводы и зафиксировать наблюдения

# %% [markdown]
# ## Содержание
#
# 1. Создание БД в SQLite
# 2. SELECT, WHERE, ORDER BY
# 3. Агрегации: GROUP BY, HAVING
# 4. JOIN (inner, left, right)
# 5. Оконные функции (ROW_NUMBER, RANK, LAG)
# 6. Подзапросы и CTE
# 7. Выводы

# %%
import pandas as pd
import numpy as np
import sqlite3

# Подключение к in-memory SQLite БД
conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# %%
# Загружаем датасет и записываем в SQLite
df = pd.read_csv('../data/telco-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.to_sql('customers', conn, if_exists='replace', index=False)
print('Таблица загружена:', pd.read_sql('SELECT COUNT(*) as n FROM customers', conn))

# %% [markdown]
# ## EDA
#
# ---

# %%
# TODO

# %% [markdown]
# ## Препроцессинг
#
# ---

# %%
# TODO

# %% [markdown]
# ## Модель
#
# ---

# %%
# TODO

# %% [markdown]
# ## Оценка
#
# ---

# %%
# TODO

# %% [markdown]
# ## Выводы
#
# ---

# %%
# TODO

# %% [markdown]
# ## Итоги
#
# | Модель | Метрика | Значение |
# |-------|---------|----------|
# | ... | ... | ... |
#
# **Ключевые наблюдения:**
#
# -
# -
# -
