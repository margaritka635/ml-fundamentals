# %% [markdown]
# # Временные ряды
#
# **Датасет:** Store Sales

# %% [markdown]
# ## Цели
#
# - Изучить и применить на практике ключевые концепции темы
# - Провести полный цикл: загрузка данных → EDA → препроцессинг → модель → оценка
# - Сделать выводы и зафиксировать наблюдения

# %% [markdown]
# ## Содержание
#
# 1. Загрузка и визуализация ряда
# 2. Декомпозиция (STL)
# 3. Проверка стационарности (ADF)
# 4. ARIMA / SARIMA
# 5. Prophet
# 6. ML-подход (лаговые признаки)
# 7. Выводы

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from prophet import Prophet

# %matplotlib inline

# %%
train = pd.read_csv('../data/store-sales/train.csv', parse_dates=['date'])
print(train.shape)
train.head()

# %% [markdown]
# ## EDA
#
# ---

# %%
# TODO

# %% [markdown]
# ## Препроцессинг
#
# ---

# %%
# TODO

# %% [markdown]
# ## Модель
#
# ---

# %%
# TODO

# %% [markdown]
# ## Оценка
#
# ---

# %%
# TODO

# %% [markdown]
# ## Выводы
#
# ---

# %%
# TODO

# %% [markdown]
# ## Итоги
#
# | Модель | Метрика | Значение |
# |-------|---------|----------|
# | ... | ... | ... |
#
# **Ключевые наблюдения:**
#
# -
# -
# -
